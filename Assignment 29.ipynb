# %% [markdown]
# # Assignment 29

# %%
pip install bokeh
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#ans 1:
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
p = figure(plot_width=400, plot_height=400)
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]
p.circle(x, y, size=10)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1039">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="43db2589-fe57-4732-875f-6f25a01d246b" data-root-id="1002"></div>

# %% [markdown]
# #ans 2:
# Glyphs are the visual representations of data points in a Bokeh plot. In other words, glyphs are the shapes, markers, or lines that represent the data on the plot. Bokeh provides a wide range of glyphs, including circles, squares, triangles, lines, and more, which can be customized to fit the needs of the plot.
#
# To add glyphs to a Bokeh plot

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# create a figure object
p = figure(plot_width=400, plot_height=400)

# add circles to the plot
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]
p.circle(x, y, size=10, color='navy', alpha=0.5)

# add lines to the plot
x2 = [1, 2, 3, 4, 5]
y2 = [5, 4, 2, 7, 6]
p.line(x2, y2, line_width=2, color='red')

# display the plot
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1149">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e8c45551-d5db-47d2-96e8-50970cd606a1" data-root-id="1106"></div>

# %% [markdown]
# #ans 3:
# Bokeh provides a wide range of customization options to help you fine-tune the appearance of your plots. Here are some of the ways you can customize a Bokeh plot:
#
# Customizing Axes
# To customize the appearance of the axes in a Bokeh plot, you can use the following methods of the figure object:

# %% [markdown]
# Customizing Title
# To customize the title of a Bokeh plot, you can use the following method of the figure object:

# %% [markdown]
# Customizing Legend
# To customize the legend of a Bokeh plot, you can use the following methods:

# %% [markdown]
# #ans 4:
# A Bokeh server is a Python application that allows you to create interactive plots with real-time updates. It is built on top of the Bokeh library and provides a way to create interactive web applications that can be accessed from a web browser.
#
# With a Bokeh server, you can create plots that respond to user inputs, such as slider bars, drop-down menus, and text boxes. When the user interacts with the plot, the Bokeh server updates the plot in real-time, without the need to reload the entire page.
#
# To create a Bokeh server application, you need to define a function that creates the plot and handles any user inputs. This function is called a "callback" function, and it is registered with the Bokeh server using the curdoc() function.

# %%
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.layouts import column
from bokeh.io import curdoc
import numpy as np

# create a data source
x = np.linspace(0, 10, 100)
y = np.sin(x)
source = ColumnDataSource(data=dict(x=x, y=y))

# create a plot
plot = figure(plot_width=400, plot_height=400)
plot.line('x', 'y', source=source, line_width=2)

# define a callback function
def update_data(attrname, old, new):
    # get the current value of the slider
    freq = freq_slider.value
    
    # update the data source
    y = np.sin(freq*x)
    source.data = dict(x=x, y=y)

# create a slider
freq_slider = Slider(start=0.1, end=10, value=1, step=0.1, title="Frequency")
freq_slider.on_change('value', update_data)

# create a layout
layout = column(freq_slider, plot)

# register the callback function with the Bokeh server
curdoc().add_root(layout)

# %% [markdown]
# #ans 5:
# Bokeh provides several ways to embed plots into web applications built with popular Python web frameworks like Flask and Django.
#
# Here are the basic steps to embed a Bokeh plot into a Flask or Django web application:
#
# Create a Bokeh plot in your Python code using the bokeh.plotting module.
#
# Add any interactive elements (e.g., widgets) to the plot.
#
# Create an HTML file that includes a div element with a unique ID where the plot will be displayed.
#
# Use the bokeh.embed module to generate a script that initializes the plot in the web page, and a div tag that references the plot's unique ID.
#
# In your Flask or Django code, create a view function that renders the HTML file and passes the generated script and div tag to the template context.
#
# In the HTML template, include the generated script and div tag in the appropriate places to display the plot.
