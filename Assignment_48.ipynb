# %%
#assignment 48

# %%
# ans 1:
import pandas as pd

# %%
df=pd.read_excel('flight_price.xlsx')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.shape
# Out:
# (10683, 11)

# %%
row=df.shape[0]

# %%
col=df.shape[1]

# %%
row
# Out:
# 10683

# %%
col
# Out:
# 11

# %%
#ans 2:
import matplotlib.pyplot as plt
plt.hist(df['Price'], bins=20)
plt.xlabel('Flight Price')
plt.ylabel('Frequency')
plt.title('Distribution of Flight Prices')
plt.show()

# %%
#ans 3:
min_price=df['Price'].min()

# %%
max_price=df['Price'].max()

# %%
range_price=max_price-min_price

# %%
print(min_price,max_price,range_price)
# Out:
# 1759 79512 77753

# %%
#ans 4:
import seaborn as sns
sns.boxplot(x='Airline', y='Price', data=df)
plt.xlabel('Airline')
plt.ylabel('Flight Price')
plt.title('Price of Flights by Airline')
plt.show()

# %%
#ans 5:
import seaborn as sns
sns.boxplot(x='Price', data=df)
plt.xlabel('Airline')
plt.ylabel('Flight Price')
plt.title('Price of Flights by Airline')
plt.show()

# %% [markdown]
# ans 6:To identify the peak travel season from the Flight Price dataset, there are several features that we could analyze. Here are some potential features:
#
# Departure date: Analyzing flight prices by month or day of the week could reveal patterns in peak travel times.
#
# Destination: Analyzing flight prices to different destinations could reveal when certain locations are in high demand.
#
# Airline: Analyzing flight prices by airline could reveal when certain airlines have more flights and are therefore more popular.
#
# Flight duration: Analyzing flight prices by flight duration could reveal when people are more likely to take longer trips.
#
# Once we have identified the features to analyze, we could use statistical techniques such as regression analysis or time series analysis to identify patterns and trends in the data. We could also create visualizations such as line charts, bar graphs, or heatmaps to help us identify the peak travel season more easily.
#
# To present our findings to the boss, we could create a report or a presentation that highlights the key insights and trends we have identified. We could include visualizations and tables that clearly show the data and explain the insights we have uncovered. Additionally, we could provide recommendations for how the travel agency could use this information to optimize their pricing and marketing strategies during the peak travel season.

# %% [markdown]
# ans 7:To identify trends in flight prices from the Flight Price dataset, there are several features that we could analyze. Here are some potential features:
#
# Time: Analyzing flight prices over time could reveal trends in pricing patterns over weeks, months, or even years.
#
# Airline: Analyzing flight prices by airline could reveal which airlines tend to have higher or lower prices and how those prices change over time.
#
# Destination: Analyzing flight prices to different destinations could reveal patterns in pricing based on location and seasonality.
#
# Flight duration: Analyzing flight prices by flight duration could reveal whether longer or shorter flights tend to have higher prices.
#
# Once we have identified the features to analyze, we could use statistical techniques such as regression analysis or time series analysis to identify patterns and trends in the data. We could also create visualizations such as line charts, scatter plots, or heatmaps to help us identify trends more easily.
#
# To present our findings to the team, we could create a report or a presentation that highlights the key insights and trends we have identified. We could include visualizations and tables that clearly show the data and explain the insights we have uncovered. Additionally, we could provide recommendations for how the flight booking website could use this information to optimize their pricing and marketing strategies.

# %% [markdown]
# ans 8:To identify the factors that affect flight prices from the Flight Price dataset, there are several features that we could analyze. Here are some potential features:
#
# Time: Analyzing flight prices over time could reveal how prices change based on the season, day of the week, and time of day.
#
# Airline: Analyzing flight prices by airline could reveal how prices differ between airlines and which airlines tend to have higher or lower prices.
#
# Destination: Analyzing flight prices to different destinations could reveal how prices vary based on location, seasonality, and competition.
#
# Flight duration: Analyzing flight prices by flight duration could reveal how prices differ for shorter or longer flights.
#
# Distance: Analyzing flight prices by distance could reveal how prices change based on the length of the flight.
#
# Departure and arrival airports: Analyzing flight prices by departure and arrival airports could reveal how prices differ based on location and competition.
#
# Once we have identified the features to analyze, we could use statistical techniques such as regression analysis or machine learning algorithms to identify the most important factors that affect flight prices. We could also create visualizations such as scatter plots or heatmaps to help us identify correlations between features and flight prices.
#
# To present our findings to the management team, we could create a report or a presentation that highlights the key factors that affect flight prices and how they impact the business. We could include visualizations and tables that clearly show the data and explain the insights we have uncovered. Additionally, we could provide recommendations for how the airline company could use this information to optimize their pricing and marketing strategies and improve their competitiveness in the market.

# %%
#ans 9:
tf=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
tf.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
row1,col1=tf.shape[0],tf.shape[1]

# %%
row1,col1
# Out:
# (10841, 13)

# %%
#ans 10:
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#ans 10:
rating_data = tf[['Category', 'Rating']]

# Group the data by app category and calculate the average rating for each category
grouped_ratings = rating_data.groupby('Category').mean().reset_index()

# Create the boxplot using Seaborn
sns.boxplot(x='Category', y='Rating', data=grouped_ratings)
# Out:
# <Axes: xlabel='Category', ylabel='Rating'>

# %%
#ans 11:
print(tf.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
#ans 12:
size = tf['Size']
rating = tf['Rating']

# create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(size, rating, alpha=0.5)
plt.xlabel('App Size')
plt.ylabel('Rating')
plt.title('Relationship between App Size and Rating')
plt.show()

# %%
#ans 13:mean_prices = df.groupby('Type')['Price'].mean()

# create a bar chart plt.figure(figsize=(10, 6))
plt.bar(mean_prices.index, mean_prices.values)
plt.xlabel('App Type')
plt.ylabel('Mean Price')
plt.title('Average Prices by App Type')
plt.show()#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-6310f4134314> in <cell line: 4>()
#       2
#       3 # create a bar chart plt.figure(figsize=(10, 6))
# ----> 4 plt.bar(mean_prices.index, mean_prices.values)
#       5 plt.xlabel('App Type')
#       6 plt.ylabel('Mean Price')
#
# NameError: name 'mean_prices' is not defined

# %%
#ans 14:
app_name = tf['App']
installs = tf['Installs']

# create a frequency table and sort by number of installs
freq_table = pd.DataFrame({'App': app_name, 'Installs': installs})
freq_table = freq_table.groupby('App').sum().sort_values(by='Installs', ascending=False)

# display the top 10 most popular apps
print(freq_table.head(10))
# Out:
#                                                                                       Installs
# App
# Life Made WI-Fi Touchscreen Photo Frame                                                   Free
# Candy Crush Saga                             500,000,000+500,000,000+500,000,000+500,000,00...
# Temple Run 2                                 500,000,000+500,000,000+500,000,000+500,000,00...
# Viber Messenger                              500,000,000+500,000,000+500,000,000+500,000,00...
# Snapchat                                      500,000,000+500,000,000+500,000,000+500,000,000+
# imo free video calls and chat                 500,000,000+500,000,000+500,000,000+500,000,000+
# Pou                                           500,000,000+500,000,000+500,000,000+500,000,000+
# UC Browser - Fast Download Private & Secure               500,000,000+500,000,000+500,000,000+
# LINE: Free Calls & Messages                               500,000,000+500,000,000+500,000,000+
# ...

# %% [markdown]
# To identify the most popular app categories in the Google Playstore dataset, we can use the following approach:
#
# Load the Google Playstore dataset and explore its features to understand the available data.
#
# Identify the variables that could be relevant to app popularity. These variables may include the number of installs, ratings, reviews, category, size, and price.
#
# Clean and preprocess the data to ensure that it is accurate and consistent.
#
# Analyze the data to identify the most popular app categories based on the number of installs or ratings.
#
# Use data visualization techniques such as bar charts or pie charts to present the results to the company.
#
# Make recommendations to the company based on the analysis, such as which app categories are the most popular and what features those apps tend to have.
#
# Specifically, to analyze the Google Playstore dataset to identify the most popular app categories, we can group the apps by category and calculate the total number of installs or average rating for each category. We can then create a bar chart or pie chart to visualize the results and identify the most popular categories. We may also want to explore other variables such as size or price to see if they are related to app popularity.
#
# Based on the analysis, we can make recommendations to the company on what types of apps are in high demand and what features they should focus on when developing their app. We may also suggest ways to differentiate their app from others in the same category, such as by offering unique features or a more user-friendly interface.
